# %%
Reading data from actual data avalable database
1. 20220716_CastellouDeBages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import glob

# %%
class PontdeVilomara:
    def __init__(self, filename):
        # Load the DataFrame
        self.df = pd.read_csv(filename, delimiter='\t', header=2)
        self.filename = filename

        # Extract latitude and longitude
        with open(filename, 'r') as file:
            first_line = file.readline().strip()
        data = first_line.split(' ')

        lat_lon = data[6]
        data2 = lat_lon.split(',')
        lat = data2[0]
        lon = data2[1]

        self.lat = lat
        self.lon = lon

        # Extract date
        with open(filename, 'r') as file:
            file.readline()  # Skip the first line
            second_line = file.readline().strip()
        data = second_line.split(' ')
        date = data[1]
        date_string = str(date)
        date_object = datetime.strptime(date_string, '%Y%m%d')
        self.date_only = date_object.date()

        # Define function to convert time range to datetime
        def convert_time_range_to_datetimes(time_range_str, date_str=self.date_only):
            start_time_str, end_time_str = time_range_str.split(' - ')
            start_datetime = datetime.strptime(f'{date_str} {start_time_str}', '%Y-%m-%d %H:%M')
            return pd.Series([start_datetime])
            

        # Apply the function to the DataFrame
        self.df[['date', ]] = self.df['Periode[UTM]'].apply(lambda x: pd.Series(convert_time_range_to_datetimes(x)))

        self.df.drop(columns=['Periode[UTM]'], inplace=True) 

# Example usage
filename = '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx_20220716_CastellouDeBages.csv'
pdVWs = PontdeVilomara(filename)
pdVWs.df
# Out:
#     TM[C]   TX[C]   TN[C]  HRM[%]  PPT[mm]  VVM10m[km/h]   DVM10m[graus]  \
# 0    24.4    24.7    24.1      43      0.0            4.7             27
# 1    23.7    24.7    22.8      46      0.0            7.9             36
# 2    22.6    22.9    22.3      49      0.0            5.4             21
# 3    23.1    23.3    22.9      48      0.0            5.0             20
# 4    22.5    22.9    22.3      50      0.0            6.1             11
# 5    22.2    22.4    22.0      51      0.0            4.3              7
# 6    21.8    22.0    21.7      51      0.0            5.4              0
# 7    21.3    21.8    21.0      53      0.0            3.2            355
# 8    20.7    21.2    20.4      56      0.0            3.6             20
# 9    21.4    21.7    20.7      54      0.0            8.3             11
# 10   22.1    22.4    21.6      52      0.0            6.8              5
# 11   22.9    23.3    22.3      50      0.0            2.2            353
# ...

# %%
2. 20220717_CastellouDeBages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

class PontdeVilomara:
    def __init__(self, filename):
        # Load the DataFrame
        self.df = pd.read_csv(filename, delimiter='\t', header=2)
        self.filename = filename

        # Extract latitude and longitude
        with open(filename, 'r') as file:
            first_line = file.readline().strip()
        data = first_line.split(' ')

        lat_lon = data[6]
        data2 = lat_lon.split(',')
        lat = data2[0]
        lon = data2[1]

        self.lat = lat
        self.lon = lon

        # Extract date
        with open(filename, 'r') as file:
            file.readline()  # Skip the first line
            second_line = file.readline().strip()
        data = second_line.split(' ')
        date = data[1]
        date_string = str(date)
        date_object = datetime.strptime(date_string, '%Y%m%d')
        self.date_only = date_object.date()

        # Define function to convert time range to datetime
        def convert_time_range_to_datetimes(time_range_str, date_str=self.date_only):
            start_time_str, end_time_str = time_range_str.split(' - ')
            start_datetime = datetime.strptime(f'{date_str} {start_time_str}', '%Y-%m-%d %H:%M')
            return pd.Series([start_datetime])
            

        # Apply the function to the DataFrame
        self.df[['date', ]] = self.df['Periode[UTM]'].apply(lambda x: pd.Series(convert_time_range_to_datetimes(x)))

        self.df.drop(columns=['Periode[UTM]'], inplace=True) 

# Example usage
filename = '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx_20220717_CastellouDeBages.csv'
pdVWs = PontdeVilomara(filename)
pdVWs.df
# Out:
#     TM[C]   TX[C]   TN[C]  HRM[%]  PPT[mm]  VVM10m[km/h]   DVM10m[graus]  \
# 0    24.1    24.3    23.9      44        0            6.1             10
# 1    24.1    24.2    23.9      44        0            6.1             11
# 2    23.6    24.0    23.2      46        0            5.0             16
# 3    23.4    23.5    23.2      47        0            6.8              8
# 4    23.2    23.4    22.9      47        0            7.6             10
# 5    22.7    22.9    22.6      49        0            6.5             12
# 6    22.6    22.8    22.4      50        0            6.1             11
# 7    22.5    22.8    21.5      50        0            3.6            352
# 8    21.2    21.5    20.9      54        0            2.5            346
# 9    21.0    21.1    20.8      55        0            1.4             14
# 10   21.4    22.6    20.6      54        0            2.2            339
# 11   23.6    24.3    22.7      48        0            1.4             12
# ...

# %%
3. combine 20220716 _17_CastellouDeBages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

class PontdeVilomara:
    def __init__(self, filename):
        # Load the DataFrame
        self.df = pd.read_csv(filename, delimiter='\t', header=2)
        self.filename = filename

        # Extract latitude and longitude
        with open(filename, 'r') as file:
            first_line = file.readline().strip()
        data = first_line.split(' ')

        lat_lon = data[6]
        data2 = lat_lon.split(',')
        lat = data2[0]
        lon = data2[1]

        self.lat = lat
        self.lon = lon

        # Extract date
        with open(filename, 'r') as file:
            file.readline()  # Skip the first line
            second_line = file.readline().strip()
        data = second_line.split(' ')
        date = data[1]
        date_string = str(date)
        date_object = datetime.strptime(date_string, '%Y%m%d')
        self.date_only = date_object.date()

        # Define function to convert time range to datetime
        def convert_time_range_to_datetimes(time_range_str, date_str=self.date_only):
            start_time_str, end_time_str = time_range_str.split(' - ')
            start_datetime = datetime.strptime(f'{date_str} {start_time_str}', '%Y-%m-%d %H:%M')
            return pd.Series([start_datetime])
            
        # Apply the function to the DataFrame
        self.df[['date']] = self.df['Periode[UTM]'].apply(lambda x: pd.Series(convert_time_range_to_datetimes(x)))

        self.df.drop(columns=['Periode[UTM]'], inplace=True)

    def concatenate_with(self, other_df, axis=0, ignore_index=False):
       
        return pd.concat([self.df, other_df], axis=axis, ignore_index=ignore_index)
    
    def display_data(self):
        """Display the DataFrame."""
        print(self.df)

# Example usage
filename1 = '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx_20220716_CastellouDeBages.csv'
filename2 = '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx_20220717_CastellouDeBages.csv'

# Create instances for each file
pdVWs1 = PontdeVilomara(filename1)
pdVWs2 = PontdeVilomara(filename2)

# Concatenate DataFrames from both instances
concatenated_df = pdVWs1.concatenate_with(pdVWs2.df)

# Display the concatenated DataFrame
print(concatenated_df)
# Out:
#     TM[C]   TX[C]   TN[C]  HRM[%]  PPT[mm]  VVM10m[km/h]   DVM10m[graus]  \
# 0    24.4    24.7    24.1      43      0.0            4.7             27
# 1    23.7    24.7    22.8      46      0.0            7.9             36
# 2    22.6    22.9    22.3      49      0.0            5.4             21
# 3    23.1    23.3    22.9      48      0.0            5.0             20
# 4    22.5    22.9    22.3      50      0.0            6.1             11
# ..    ...     ...     ...     ...      ...            ...            ...
# 43   25.2    25.7    24.6      38      0.0            2.2            346
# 44   24.8    25.3    24.0      39      0.0            1.8            352
# 45   24.3    24.8    23.8      40      0.0            3.2            310
# 46   24.6    25.0    24.0      39      0.0            3.2            355
# 47   23.9    24.3    23.4      42      0.0            0.7             52
#
#      VVX10m[km/h]   RS[W/m2]                date
# ...

# %%
4. combined Rellinars station data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import re

class PontdeVilomara:
    def __init__(self, filename):
        # Load the DataFrame
        self.df = pd.read_csv(filename, delimiter='\t', header=2)
        self.filename = filename

        # Extract date
        with open(filename, 'r') as file:
            file.readline()  # Skip the first line
            second_line = file.readline().strip()
        data = second_line.split(' ')
        date = data[1]
        date_string = str(date)
        date_object = datetime.strptime(date_string, '%Y%m%d')
        self.date_only = date_object.date()

        # Define function to convert time range to datetime
        def convert_time_range_to_datetimes(time_range_str, date_str=self.date_only):
            start_time_str, end_time_str = time_range_str.split(' - ')
            start_datetime = datetime.strptime(f'{date_str} {start_time_str}', '%Y-%m-%d %H:%M')
            return pd.Series([start_datetime])
            
        # Apply the function to the DataFrame
        self.df[['date']] = self.df['Periode[UTM]'].apply(lambda x: pd.Series(convert_time_range_to_datetimes(x)))

        self.df.drop(columns=['Periode[UTM]'], inplace=True)

    def concatenate_with(self, other_df, axis=0, ignore_index=False):
        return pd.concat([self.df, other_df], axis=axis, ignore_index=ignore_index)
    
    def display_data(self):
        """Display the DataFrame."""
        print(self.df)

# Example usage
filename1 = '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx_20220716_Rellinars.csv'
filename2 = '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx_20220717_Rellinars.csv'

# Create instances for each file
pdVWs1 = PontdeVilomara(filename1)
pdVWs2 = PontdeVilomara(filename2)

# Concatenate DataFrames from both instances
concatenated_df = pdVWs1.concatenate_with(pdVWs2.df)

# Display the concatenated DataFrame
print(concatenated_df)
# Out:
#     TM[C]   TX[C]   TN[C]  HRM[%]  PPT[mm]  VVM10m[km/h]   DVM10m[graus]  \
# 0    24.1    24.6    23.5      39      0.0            3.2             71
# 1    23.3    23.5    23.1      41      0.0            2.5             73
# 2    23.0    23.3    22.5      46      0.0            0.4            292
# 3    22.2    22.5    21.6      48      0.0            0.4             75
# 4    21.2    21.6    20.9      49      0.0            1.4             78
# ..    ...     ...     ...     ...      ...            ...            ...
# 43   25.9    26.6    25.4      34      0.0            2.2             64
# 44   25.4    25.5    24.8      34      0.0            2.2             65
# 45   24.3    24.7    23.9      38      0.0            4.3             62
# 46   23.8    24.3    23.3      39      0.0            2.9             75
# 47   23.4    23.6    23.0      40      0.0            4.0             66
#
#      VVX10m[km/h]   RS[W/m2]                date
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import re

class PontdeVilomara:
    def __init__(self, filenames):
        # Ensure filenames is a list
        if not isinstance(filenames, list):
            filenames = [filenames]
        
        # Load and concatenate DataFrames from all files
        self.df = pd.concat([self._load_file(file) for file in filenames], ignore_index=True)
    
    def _load_file(self, filename):
        # Load a single file into a DataFrame
        df = pd.read_csv(filename, delimiter='\t', header=2)
        
        # Extract date from the file
        with open(filename, 'r') as file:
            file.readline()  # Skip the first line
            second_line = file.readline().strip()
        data = second_line.split(' ')
        date = data[1]
        date_string = str(date)
        date_object = datetime.strptime(date_string, '%Y%m%d')
        date_only = date_object.date()
        
        # Define function to convert time range to datetime
        def convert_time_range_to_datetimes(time_range_str, date_str=date_only):
            start_time_str, end_time_str = time_range_str.split(' - ')
            start_datetime = datetime.strptime(f'{date_str} {start_time_str}', '%Y-%m-%d %H:%M')
            return pd.Series([start_datetime])
        
        # Apply the function to the DataFrame
        df[['date']] = df['Periode[UTM]'].apply(lambda x: pd.Series(convert_time_range_to_datetimes(x)))
        df.drop(columns=['Periode[UTM]'], inplace=True)
        
        return df

    def display_data(self):
        """Display the DataFrame."""
        print(self.df)

# Example usage
#filenames = glob.glob( '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx*{:s}.csv'.format(stationame)
filenames = [
    '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx_20220716_CastellouDeBages.csv', 
    '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx_20220717_CastellouDeBages.csv',
    
]

# Create an instance for all files
pdVWs = PontdeVilomara(filenames)

# Display the concatenated DataFrame
pdVWs.display_data()
# Out:
#     TM[C]   TX[C]   TN[C]  HRM[%]  PPT[mm]  VVM10m[km/h]   DVM10m[graus]  \
# 0    24.4    24.7    24.1      43      0.0            4.7             27
# 1    23.7    24.7    22.8      46      0.0            7.9             36
# 2    22.6    22.9    22.3      49      0.0            5.4             21
# 3    23.1    23.3    22.9      48      0.0            5.0             20
# 4    22.5    22.9    22.3      50      0.0            6.1             11
# ..    ...     ...     ...     ...      ...            ...            ...
# 91   25.2    25.7    24.6      38      0.0            2.2            346
# 92   24.8    25.3    24.0      39      0.0            1.8            352
# 93   24.3    24.8    23.8      40      0.0            3.2            310
# 94   24.6    25.0    24.0      39      0.0            3.2            355
# 95   23.9    24.3    23.4      42      0.0            0.7             52
#
#      VVX10m[km/h]   RS[W/m2]                date
# ...

# %%
filenames = glob.glob( '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx*{:s}.csv'.format(stationame)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import re

class PontdeVilomara:
    def __init__(self, filenames):
        # Ensure filenames is a list
        if not isinstance(filenames, list):
            filenames = [filenames]
        
        # Load and concatenate DataFrames from all files
        self.df = pd.concat([self._load_file(file) for file in filenames], ignore_index=True)
    
    def _load_file(self, filename):
        # Load a single file into a DataFrame
        df = pd.read_csv(filename, delimiter='\t', header=2)
        
        # Extract date from the file
        with open(filename, 'r') as file:
            file.readline()  # Skip the first line
            second_line = file.readline().strip()
        data = second_line.split(' ')
        date = data[1]
        date_string = str(date)
        date_object = datetime.strptime(date_string, '%Y%m%d')
        date_only = date_object.date()
        
        # Define function to convert time range to datetime
        def convert_time_range_to_datetimes(time_range_str, date_str=date_only):
            start_time_str, end_time_str = time_range_str.split(' - ')
            start_datetime = datetime.strptime(f'{date_str} {start_time_str}', '%Y-%m-%d %H:%M')
            return pd.Series([start_datetime])
        
        # Apply the function to the DataFrame
        df[['date']] = df['Periode[UTM]'].apply(lambda x: pd.Series(convert_time_range_to_datetimes(x)))
        df.drop(columns=['Periode[UTM]'], inplace=True)
        
        return df

    def display_data(self):
        """Display the DataFrame."""
        print(self.df)

# Example usage
filenames = [
    '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx_20220716_Rellinars.csv', 
    '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx_20220717_Rellinars.csv',
    
]

# Create an instance for all files
pdVWs = PontdeVilomara(filenames)

# Display the concatenated DataFrame
pdVWs.display_data()
# Out:
#     TM[C]   TX[C]   TN[C]  HRM[%]  PPT[mm]  VVM10m[km/h]   DVM10m[graus]  \
# 0    24.1    24.6    23.5      39      0.0            3.2             71
# 1    23.3    23.5    23.1      41      0.0            2.5             73
# 2    23.0    23.3    22.5      46      0.0            0.4            292
# 3    22.2    22.5    21.6      48      0.0            0.4             75
# 4    21.2    21.6    20.9      49      0.0            1.4             78
# ..    ...     ...     ...     ...      ...            ...            ...
# 91   25.9    26.6    25.4      34      0.0            2.2             64
# 92   25.4    25.5    24.8      34      0.0            2.2             65
# 93   24.3    24.7    23.9      38      0.0            4.3             62
# 94   23.8    24.3    23.3      39      0.0            2.9             75
# 95   23.4    23.6    23.0      40      0.0            4.0             66
#
#      VVX10m[km/h]   RS[W/m2]                date
# ...

# %%
stationame = 'CastellouDeBages'

filenames = sorted(glob.glob( '/data/IMFSE/PythonCourse/PontdeVilomara/WeatherStations/wx*{:s}.csv'.format(stationame)))

# Create instances for each file
pdVWs = []
for filename in filenames:
    pdVWs_ = PontdeVilomara(filename)
    lat, lon = pdVWs_.lat, pdVWs_.lon
    pdVWs.append(pdVWs_.df)

print(pdVWs[0].lat)
# Concatenate DataFrames from both instances
concatenated_df = pd.concat(pdVWs)

# Display the concatenated DataFrame
print(concatenated_df)
